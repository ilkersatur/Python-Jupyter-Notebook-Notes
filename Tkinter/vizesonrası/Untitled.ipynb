# %%
kayitliid=""
kayitlisifre=""
hak=3

def giris():
    global hak
    
    aka=kadi.get()
    asfre=sifre.get()
    
    if((aka==kayitliid)and(asfre==kayitlisifre)):
       
        yenipencere=Toplevel(main)
        yenipencere.title("Calculator")
        yenipencere.geometry("400x400")
        
        sayi1=Entry(yenipencere,font=("Arial",15))
        sayi2=Entry(yenipencere,font=("Arial",15))
        sayi1.place(x=50,y=50)
        sayi2.place(x=50,y=100)
        listbox=Listbox(yenipencere)
        listbox.insert(1,"+")  
        listbox.insert(2, "-")  
        listbox.insert(3, "*")  
        listbox.insert(4, "/")  
        listbox.place(x=250,y=50)
        
        hesapla=Button(yenipencere,text="hesapla",font=("Arial",20))
        hesapla.place(y=150,x=50)
        
        

    if((aka!=kayitliid)and(asfre==kayitlisifre)):
        girisyap.configure(text="Yanlış")
        hak-=1
    
    if((aka!=kayitliid)and(asfre!=kayitlisifre)):
        girisyap.configure(text="Yanlış")
        hak-=1

    if((aka==kayitliid)and(asfre!=kayitlisifre)):
        girisyap.configure(text="Yanlış")
        hak-=1
    if(hak==0):
        main.withdraw()
        hata=Toplevel(main)
        hata.title("HATA")
        hata.configure(bg="red")
        baslik5=Label(hata,text="BLOKE",bg="RED")
        baslik5.pack()

        

from tkinter import*
main=Tk()
main.geometry("400x300")
main.configure(bg="green")
main.title("kullanıcı girişi")

baslik1=Label(main,text="Login",bg="white")
baslik2=Label(main,text="Login",font=("Arial",20))
baslik3=Label(main,text="ID",font=("Arial",20))
baslik4=Label(main,text="Şifre",font=("Arial",20))

girisyap=Button(main,text="Login",font=("Arial",20),command=giris)

kadi=Entry(main,font=("Arial",15))
sifre=Entry(main,font=("Arial",15))


baslik1.place(x=0,y=0,relheight=100,width=130)
baslik2.place(x=50,y=20)
baslik3.place(x=60,y=100)
baslik4.place(x=60,y=150)
kadi.place(x=150,y=100)
sifre.place(x=150,y=150)
girisyap.place(x=150,y=200)

main.mainloop()

# %%
    from tkinter import*
    main=Tk()
    main.geometry("400x300")
    main.configure(bg="green")
    devre=PhotoImage(file="devre1.jpeg")
    cerceve=Label(main,image=devre)
    cerceve.place(x=0,y=0)
