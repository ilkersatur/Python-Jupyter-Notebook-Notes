# %% [markdown]
# # 1180301047_İlker_ŞATUR_MM

# %% [markdown]
# ### Soru 2

# %%
t1=7
t2=11
for i in range(1,5,3):
    t1=t1+i
    for j in range(4,1,-3):
        if(i!=j):
            t1=t1+j
        else:
            t2=t2+j
        t1=t1-2
        t2=t2*i
print(2*t1,t2/2)
# Out:
# 24 30.0

# %% [markdown]
# # Soru 1

# %% [markdown]
# ![image.png](attachment:bf6eafb8-d659-4467-a20c-1ae6771e17ad.png)

# %%
h=int(input("yükseklik"))
Vo=int(input("ilk hız"))
yer=input("yer yazınız: dünya, mars, ay, güneş")

if(yer=="dünya"):
    g=9,807
    t=((2*h)/g)**(1/2)
    x=Vo*t
    Vx=Vo
    Vy=g*t
    V=(Vx**2)+(Vy**2)**(1/2)
elif(yer=="mars"):
    g=3,72
    t=((2*h)/g)**(1/2)
    x=Vo*t
    Vx=Vo
    Vy=g*t
    V=(Vx**2)+(Vy**2)**(1/2)
elif(yer=="ay"):
    g=1,62
    t=((2*h)/g)**(1/2)
    x=Vo*t
    Vx=Vo
    Vy=g*t
    V=(Vx**2)+(Vy**2)**(1/2)
elif(yer=="güneş"):
    g=274
    t=((2*h)/g)**(1/2)
    x=Vo*t
    Vx=Vo
    Vy=g*t
    V=(Vx**2)+(Vy**2)**(1/2)
else:
    print("hatalı yazım")
    
print("hız",V,"mesafe",x,"süre",t)
