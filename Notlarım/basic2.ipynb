# %%
sayi1=int(input("1"))
sayi2=int(input("2"))
print(sayi1+sayi2)

# %% [markdown]
# ### kullanıcıdn mesaj alan

# %%
mesaj=input("mesajını yaz")
print(mesaj)
# Out:
# mesajını yaz selam
# selam

# %%
ad=input("ad")
sad=input("soyadd")
yas=input("yaş")
print("ad",ad,"soyad",sad,"yaş",yas)
# Out:
# ad ilker
# soyadd şatur
# yaş 21
# ad ilker soyad şatur yaş 21

# %%
s1=int(input("sayi1"))
s2=int(input("sayi2"))
toplam=s1+s2
carpim=s1*s2
ort=toplam/2
print("toplam:{}, çarpım:{}, ort:{},".format(toplam,carpim,ort))
# Out:
# sayi1 10
# sayi2 20
# toplam:30, çarpım:200, ort:15.0,
