# %% [markdown]
# # Sözlük

# %%
sözlük={"ekmek":"bread","su":"wather","pc":"computer"}

# %%
sözlük.items()
# Out:
# dict_items([('ekmek', 'bread'), ('su', 'wather'), ('pc', 'computer')])

# %%
sözlük.keys()
# Out:
# dict_keys(['ekmek', 'su', 'pc'])

# %%
sözlük.values()
# Out:
# dict_values(['bread', 'wather', 'computer'])

# %%
s={"1":"bir","2":"iki","3":"üç"}
s.get("1")
# Out:
# 'bir'

# %%
s.get("2")
# Out:
# 'iki'

# %% [markdown]
# # iç içe liste

# %%
liste=[[1,2,3],[3,2,1,],(4,5,6)]
liste[1]
# Out:
# [3, 2, 1]

# %%
liste[0][2]
# Out:
# 3

# %%
liste2=[[[1,2,3],[3,2,1,],(4,5,6)]]
liste2[0][0][0]
# Out:
# 1
