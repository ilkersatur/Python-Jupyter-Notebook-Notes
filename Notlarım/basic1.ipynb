# %% [markdown]
# # NOTLAR

# %%
sayi=5

# %%
sayi
# Out:
# 5

# %%
sayi+10
# Out:
# 15

# %%
print(sayi)
# Out:
# 5

# %%
sayi1=10
sayi2=20
sayi1+sayi2
# Out:
# 30

# %%
29%3
# Out:
# 2

# %%
3**4
# Out:
# 81

# %%
"selam"
# Out:
# 'selam'

# %%
'selam'
# Out:
# 'selam'

# %%
karakter="selam"
print(karakter)
# Out:
# selam

# %%
karakter[0]
# Out:
# 's'

# %%
karakter[0:4]
# Out:
# 'sela'

# %%
karakter[3:5]
# Out:
# 'am'

# %%
print(karakter[0])
print(karakter[1])
print(karakter[2])
print(karakter[3])
print(karakter[4])
# Out:
# s
# e
# l
# a
# m

# %%
print(karakter[-1])
print(karakter[-2])
print(karakter[-3])
print(karakter[-4])
print(karakter[-5])
# Out:
# m
# a
# l
# e
# s

# %%
kelime="ali veli mehmet"
print(kelime[::2])
print(kelime[::-1])
print(kelime[3:7:1])
# Out:
# aivl emt
# temhem ilev ila
#  vel

# %%
mantık=True
type(mantık)
# Out:
# bool

# %%
a=5
print(type(a))
a=str(a)
print(type(a))
a
# Out:
# <class 'int'>
# <class 'str'>
# '5'

# %%
tamsayı=input("sayi gir")
# Out:
# sayi gir 5

# %%
type(tamsayı)
# Out:
# str
