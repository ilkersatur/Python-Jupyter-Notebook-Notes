# %%
liste1=[3,4,5,6,]
print(liste1)
# Out:
# [3, 4, 5, 6]

# %%
liste2=[3,4,6,7]
liste1[2]
# Out:
# 5

# %%
liste2[0]
# Out:
# 3

# %%
liste1[:]
# Out:
# [3, 4, 5, 6]

# %%
liste1[2:]
# Out:
# [5, 6]

# %%
liste1[2:3]
# Out:
# [5]

# %%
liste1[-3]
# Out:
# 4

# %%
liste1[:-1]
# Out:
# [3, 4, 5]

# %%
liste1[-4:]
# Out:
# [3, 4, 5, 6]

# %% [markdown]
# # liste fonksiyonları

# %%
liste1.append(-1) #sondan ekler
liste1
# Out:
# [3, 4, 5, 6, 10, 10, -1, -1]

# %%
liste1.extend(liste2) #iki liste birleşti
liste1
# Out:
# [3, 4, 5, 6, 10, 10, -1, -1, 3, 4, 6, 7]

# %%
liste1.insert(0,10) #ekleme
liste1
# Out:
# [10, 4, 10, 10, 5, 6, 10, 10, -1, -1, 3]

# %%
liste1.pop(0) #silme
liste1
# Out:
# [4, 10, 10, 5, 6, 10, 10, -1, -1, 3]

# %%
liste1.remove(10) #kaldırır
liste1
# Out:
# [4, 5, 6, -1, -1, 3]

# %%
liste1.clear()
liste2.clear() # temizleme

# %%
liste1
# Out:
# []

# %%
liste1=[1,1,1,1,2,3,3,3,2]
liste1.count(1)  #kaçtane
# Out:
# 4

# %%
liste1.sort()
liste1
# Out:
# [1, 1, 1, 1, 2, 2, 3, 3, 3]

# %%
liste1.sort(reverse=True)
liste1
# Out:
# [3, 3, 3, 2, 2, 1, 1, 1, 1]

# %%
liste2=liste1.copy()
liste2.append(0)
liste2
# Out:
# [3, 3, 3, 2, 2, 1, 1, 1, 1, 0]

# %%
all(liste1) #0 varmı yok mu yoksa true
# Out:
# True

# %%
all(liste2)
# Out:
# False

# %%
any(liste2)
# Out:
# True

# %%
any(liste1) # 1 değer olması yeter 0 döner
# Out:
# True

# %%
liste3=[]  #değer yok 0 döndü
any(liste3)
# Out:
# False

# %%
liste1.clear()
liste2.clear()
liste3.clear()

# %%
l1=[0,2,3,4,5]
l2=[4,5,7,1]
print(len(l1),len(l2))
# Out:
# 5 4

# %%
min(l1)
# Out:
# 0

# %%
max(l2)
# Out:
# 7

# %%
sorted(l1)
# Out:
# [0, 2, 3, 4, 5]

# %%
l2.sort()
l2
# Out:
# [1, 4, 5, 7]

# %%
sorted(l2, reverse=True)
# Out:
# [7, 5, 4, 1]

# %%
sum(l2)
# Out:
# 17
