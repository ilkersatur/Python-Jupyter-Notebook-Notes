# %% [markdown]
# # 1180301047_İlker_Şatur_MM

# %% [markdown]
# # Cevap 1

# %%
saat=0
while(saat<10):
    saat+=1
    dakika=0
    print("saat : ",saat)
    while(dakika<24):
        dakika+=1
        saniye=0
        while(saniye<24):
            saniye+=1
toplam=saniye+dakika+saat
print("toplam üretilen sayı : ",toplam)
# Out:
# saat :  1
# saat :  2
# saat :  3
# saat :  4
# saat :  5
# saat :  6
# saat :  7
# saat :  8
# saat :  9
# saat :  10
# toplam üretilen sayı :  58

# %% [markdown]
# # Cevap 2

# %%
h=int(input("yükseklik"))
m1=int(input("m1 kütle"))
m2=int(input("m2 kütle"))
m3=input("m3 kütle")
harf=input("harf giriniz: dünya için d , ay için a, güneş için g"+" çıkmak için q basınız ")
mt=m1+m2+m3

if(harf=="d"):
    g=9.807
    F=mt*g
    
elif(harf=="a"):
    g=1.62
    F=mt*g

    
elif(harf=="g"):
    g=274
    F=mt*g

elif( harf=="Q" or harf=="q"):
    break
    
else:
    print("Yanlıs harf")

# %% [markdown]
# # CEVAP 3

# %%
LIMIT = 30
a = range(LIMIT)
a[0] = 1
for i in range(1,LIMIT):
    a[i] *= a[i-1] 
    
def cos(x):
    sonuc = 0
    n = 1
    for i in range(0,LIMIT,2):
        nom = n * np.power(x,i)
        n *= -1
        f = a[i]
        sonuc+= nom / f
    return result

def sin(x):
    sonuc = 0
    n = 1
    for i in range(1,LIMIT,2):
        nom = n * np.power(x,i)
        n *= -1
        f = a[i]
        sonuc+= nom / f
    return result

def uzunluk()
    acı=int(input("açıyı giriniz"))
    def cos(acı)
    kenar1=int(input("1. kenar"))
    kenar2=int(input("2. kenar"))
    kenar3=(kenar1**2)-(kenar2**2)+(2*kenar1*kenar2*(acı))
    print("3. kenar:",kenar3)
    return

def alan()
    def sin(acı)
    kenar1=int(input("1. kenar"))
    kenar2=int(input("2. kenar"))
    s=(0.5)*kenar1*kenar2*acı
    print("alan : ",acı)
    return

# %% [markdown]
# # Uzunluk
# ![image.png](attachment:f1ed73eb-6372-42b2-ae48-3eb35d5b9b8d.png)

# %% [markdown]
# # ALAN
# ![image.png](attachment:c8629e14-eb4c-460b-92e7-b8c0f7b0e032.png)
